# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from matplotlib.patches import Patch
from datetime import datetime, timedelta

sns.set_style({'font.sans-serif':'Laksaman'})
#sns.set_style('whitegrid', {'font.sans-serif':'Laksaman'})

# %%
Country = 'France'

# %%
#dr = pd.read_csv("./datasets_clean/all_reactors.csv")
dr = pd.read_csv("./datasets_clean/2021Table14_clean.csv")

dr = dr.loc[dr['Country']==Country.upper(), :]
#dr = da.sort_values(by='Start')[0:100].copy(deep=True)

## Add order for plotting
dr['current_num'] = np.arange(len(dr))
dr['ctime_y'] = dr["Construction_time"]/365.0

##
# Since the first reactor in the database starts at 1951, we round down the axis to 1950, to have round numbers
mintime = datetime(1950, 1, 1)#datetime.strptime(min(dr['Start']), "%Y-%m-%d")
maxtime = datetime(2020, 12, 31)

endtime_int = (maxtime-mintime).days/365.0

dr['ctime_start'] = (pd.to_datetime(dr['Start']) - mintime).dt.days/365.0

lendays = (maxtime-mintime).days
leny = lendays/365
dr = dr.sort_values(by='Start', ascending=False)

#### Color type
#array(['N4 REP 1450', 'P4 REP 1300', 'CP2', 'CP1', nan, 'CP0']
m_dict = {'N4 REP 1450':'#377eb8',
          'P4 REP 1300':'#ff7f00',
          'CP2':'#4daf4a',
          'CP1':'#f781bf',
          'CP0':'#a65628',
           np.nan:'#dede00',
          'HWLWR':'#999999',
          'HTGR ':'#dede00',
          'HWGCR':'#dede00',
          'SGHWR':'#dede00',
          'X    ':'#dede00'}

dr['model_type'] = dr['Model']
dr.replace({"model_type": m_dict}, inplace=True)
dr.reset_index(inplace=True, drop=True)

#                  , , ,
#                  , , 
#c_dict = {'PWR  ':'#E64646', 'BWR  ':'#7FFF00', 'GCR  ':'#E69646', 'PHWR ':'#E69646','FBR  ':'#3475D0', 'LWGR ':'#8A7C79','HWLWR':'#3475D0','HTGR ':'#3475D0', 'HWGCR':'#3475D0', 'SGHWR':'#3475D0', 'X    ':'#3475D0'}
dr['color_type'] = dr['Type']
dr.replace({"color_type": c_dict}, inplace=True)
dr.reset_index(inplace=True, drop=True)


#### Color type
c_dict = {'PWR  ':'#377eb8',
          'BWR  ':'#ff7f00',
          'GCR  ':'#4daf4a',
          'PHWR ':'#f781bf',
          'FBR  ':'#a65628',
          'LWGR ':'#984ea3',
          'HWLWR':'#999999',
          'HTGR ':'#dede00',
          'HWGCR':'#dede00',
          'SGHWR':'#dede00',
          'X    ':'#dede00'}

# %%
dr.head()
# Out:
#   Country      Code       Name   Type        Model  Thermal  Gross   Net  \
# 0  FRANCE  FR -73     CIVAUX-2  PWR    N4 REP 1450     4270   1561  1495
# 1  FRANCE  FR -72     CIVAUX-1  PWR    N4 REP 1450     4270   1561  1495
# 2  FRANCE  FR -70    CHOOZ B-2  PWR    N4 REP 1450     4270   1560  1500
# 3  FRANCE  FR -68    GOLFECH-2  PWR    P4 REP 1300     3817   1363  1310
# 4  FRANCE  FR -64      PENLY-2  PWR    P4 REP 1300     3817   1382  1330
#
#   Operator Supplier  ...   EAF   UCF NEA  Status  Construction_time  \
# 0      EDF     FRAM  ...  76.1  80.9   -  Online               3166
# 1      EDF     FRAM  ...  75.2  78.0   -  Online               3348
# 2      EDF     FRAM  ...  75.9  83.2   -  Online               4139
# 3      EDF     FRAM  ...  82.2  83.8   -  Online               3165
# 4      EDF     FRAM  ...  82.4  83.7   -  Online               2740
#
#    current_num    ctime_y ctime_start  model_type  color_type
# 0           55   8.673973   41.273973     #377eb8     #377eb8
# 1           54   9.172603   38.775342     #377eb8     #377eb8
# 2           53  11.339726   35.939726     #377eb8     #377eb8
# 3           52   8.671233   34.772603     #ff7f00     #377eb8
# 4           50   7.506849   34.605479     #ff7f00     #377eb8
#
# [5 rows x 24 columns]

# %%
dr.Model.unique()
# Out:
# array(['N4 REP 1450', 'P4 REP 1300', 'CP2', 'CP1', nan, 'CP0'],
#       dtype=object)

# %%
##### PLOT #####
facecolor = '#36454F'

fig, (ax, ax1) = plt.subplots(2, figsize=(6,10), gridspec_kw={'height_ratios':[11, 1]}, facecolor=facecolor)

ax.set_facecolor(facecolor)
ax1.set_facecolor(facecolor)

ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['left'].set_position(('outward', 10))
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_color('w')
ax1.spines['right'].set_visible(False)
ax1.spines['left'].set_visible(False)
ax1.spines['top'].set_visible(False)
ax1.spines['bottom'].set_visible(False)
ax1.set_xticks([])
ax1.set_yticks([])


# ticks
xticks = np.linspace(0, np.floor(endtime_int/10)*10, 8, endpoint=True)
xticks_labels = ['1950', '1960', '1970', '1980', '1990', '2000', '2010', '2020']#pd.date_range(mintime, end=maxtime, periods=8).strftime("%Y")
xticks_minor = np.linspace(0, np.floor(endtime_int/10)*10, 15, endpoint=True)
ax.set_xticks(xticks)
ax.set_xticks(xticks_minor, minor=True)
ax.set_xticklabels(xticks_labels, color='w')
ax.set_yticks([])

plt.setp([ax.get_xticklines()], color='w')

# align x axis
ax.set_xlim(0, 72.1)

# remove spines
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['left'].set_position(('outward', 10))
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_color('w')

#Make custon grid lines
ax.set_axisbelow(True)
#Make custom grid
for t in xticks_minor:
    ax.axvline(t, color='k', linestyle='--', alpha=0.5, zorder=-1)

# bars
ax.barh(dr.Name, dr.ctime_y, left=dr.ctime_start, height=0.6, color=dr.model_type)
#ax.barh(dr.Start, df.days_start_to_end, left=df.start_num, color=df.color, alpha=0.5)

ax.set_title('Reactor build times by model type, ' + Country + ', 1950-2021', color='w', loc='left', size='x-large')

plt.tight_layout()
ax.annotate('Source: Nuclear Power Reactors in the World, IAEA 2021', xy=(3, 3), xycoords='figure points', color='w')

c_dict = {'PWR  ':'#377eb8',
          'BWR  ':'#ff7f00',
          'GCR  ':'#4daf4a',
          'PHWR ':'#f781bf',
          'FBR  ':'#a65628',
          'LWGR ':'#984ea3',
          'HWLWR':'#999999',
          'HTGR ':'#dede00',#'#e41a1c',
          'HWGCR':'#dede00',
          'SGHWR':'#dede00',
          'X    ':'#dede00'}


##### LEGENDS #####
#array(['N4 REP 1450', 'P4 REP 1300', 'CP2', 'CP1', nan, 'CP0']

legend_elements = [Patch(facecolor='#a65628', label='CP0'),
                   Patch(facecolor='#dede00', label='OTHER'),
                   Patch(facecolor='#f781bf', label='CP1'),
                   Patch(facecolor='#ff7f00', label='P4 REP 1300'),
                   Patch(facecolor='#4daf4a', label='CP2'),
                   Patch(facecolor='#377eb8', label='N4 REP 1450'),
#                   Patch(facecolor='#984ea3', label='LWGR'),
#                   Patch(facecolor='#999999', label='HWLWR'),
                   
                  ]

for idx, row in dr.iterrows():
    ax.text(row.ctime_y + row.ctime_start + 0.3, idx, 
            "%.1f"%(row.ctime_y), 
            va='center', ha='left', alpha=0.8, color='w')
    ax.text(row.ctime_start - 0.3, idx, 
            row.Name, 
            va='center', ha='right', alpha=0.8, color='w', fontsize=8)

    
legend = ax1.legend(handles=legend_elements, loc='upper center', ncol=3, frameon=False)
plt.setp(legend.get_texts(), color='w')

plt.savefig("ModelBuild.png", dpi=300)
plt.show()

# %%
#

# %%
dr
# Out:
#    Country      Code                     Name   Type       Model  \
# 0    JAPAN  JP -64                   TOMARI-3  PWR    M (3-loop)
# 1    JAPAN  JP -59                    SHIKA-2  BWR          ABWR
# 2    JAPAN  JP -58    HIGASHI DORI-1 (TOHOKU)  BWR         BWR-5
# 3    JAPAN  JP -60                  HAMAOKA-5  BWR          ABWR
# 4    JAPAN  JP -57                  ONAGAWA-3  BWR         BWR-5
# 5    JAPAN  JP -56       KASHIWAZAKI KARIWA-7  BWR          ABWR
# 6    JAPAN  JP -55       KASHIWAZAKI KARIWA-6  BWR          ABWR
# 7    JAPAN  JP -46                   GENKAI-4  PWR    M (4-loop)
# 8    JAPAN  JP -54                  ONAGAWA-2  BWR         BWR-5
# 9    JAPAN  JP -47                    IKATA-3  PWR    M (3-loop)
# 10   JAPAN  JP -53       KASHIWAZAKI KARIWA-4  BWR         BWR-5
# 11   JAPAN  JP -49                  HAMAOKA-4  BWR         BWR-5
# 12   JAPAN  JP -48                    SHIKA-1  BWR         BWR-5
# 13   JAPAN  JP -52       KASHIWAZAKI KARIWA-3  BWR         BWR-5
# 14   JAPAN  JP -45                   GENKAI-3  PWR    M (4-loop)
# 15   JAPAN  JP -51                      OHI-4  PWR    M (4-loop)
# 16   JAPAN  JP -50                      OHI-3  PWR    M (4-loop)
# 17   JAPAN  JP -31                      MONJU  FBR           NaN
# 18   JAPAN  JP -39       KASHIWAZAKI KARIWA-2  BWR         BWR-5
# 19   JAPAN  JP -40       KASHIWAZAKI KARIWA-5  BWR         BWR-5
# 20   JAPAN  JP -44                   TOMARI-2  PWR    M (2-loop)
# 21   JAPAN  JP -43                   TOMARI-1  PWR    M (2-loop)
# 22   JAPAN  JP -41                  SHIMANE-2  BWR         BWR-5
# 23   JAPAN  JP -36                  HAMAOKA-3  BWR         BWR-5
# 24   JAPAN  JP -34                  TSURUGA-2  PWR    M (4-loop)
# 25   JAPAN  JP -37                   SENDAI-2  PWR    M (3-loop)
# 26   JAPAN  JP -38          FUKUSHIMA-DAINI-4  BWR           NaN
# 27   JAPAN  JP -30                 TAKAHAMA-4  PWR    M (3-loop)
# 28   JAPAN  JP -35          FUKUSHIMA-DAINI-3  BWR           NaN
# 29   JAPAN  JP -29                 TAKAHAMA-3  PWR    M (3-loop)
# 30   JAPAN  JP -22                  ONAGAWA-1  BWR           NaN
# 31   JAPAN  JP -33       KASHIWAZAKI KARIWA-1  BWR         BWR-5
# 32   JAPAN  JP -28                   SENDAI-1  PWR    M (3-loop)
# 33   JAPAN  JP -26          FUKUSHIMA-DAINI-2  BWR           NaN
# 34   JAPAN  JP -32                    IKATA-2  PWR           NaN
# 35   JAPAN  JP -27                   GENKAI-2  PWR           NaN
# 36   JAPAN  JP -25          FUKUSHIMA-DAINI-1  BWR           NaN
# 37   JAPAN  JP -24                  HAMAOKA-2  BWR           NaN
# 38   JAPAN  JP -21                    TOKAI-2  BWR         BWR-5
# 39   JAPAN  JP -18        FUKUSHIMA-DAIICHI-6  BWR           NaN
# 40   JAPAN  JP -23                    IKATA-1  PWR           NaN
# 41   JAPAN  JP -16        FUKUSHIMA-DAIICHI-4  BWR           NaN
# 42   JAPAN  JP -19                      OHI-2  PWR           NaN
# 43   JAPAN  JP -15                      OHI-1  PWR           NaN
# 44   JAPAN  JP -14                   MIHAMA-3  PWR    M (3-loop)
# 45   JAPAN  JP -20                  FUGEN ATR  HWLWR         NaN
# 46   JAPAN  JP -17        FUKUSHIMA-DAIICHI-5  BWR           NaN
# 47   JAPAN  JP -12                   GENKAI-1  PWR           NaN
# 48   JAPAN  JP -11                  HAMAOKA-1  BWR           NaN
# 49   JAPAN  JP -13                 TAKAHAMA-2  PWR    M (3-loop)
# 50   JAPAN  JP -10        FUKUSHIMA-DAIICHI-3  BWR           NaN
# 51   JAPAN  JP -7                   SHIMANE-1  BWR           NaN
# 52   JAPAN  JP -8                  TAKAHAMA-1  PWR    M (3-loop)
# 53   JAPAN  JP -9         FUKUSHIMA-DAIICHI-2  BWR           NaN
# 54   JAPAN  JP -6                    MIHAMA-2  PWR           NaN
# 55   JAPAN  JP -5         FUKUSHIMA-DAIICHI-1  BWR           NaN
# 56   JAPAN  JP -4                    MIHAMA-1  PWR           NaN
# 57   JAPAN  JP -3                   TSURUGA-1  BWR           NaN
# 58   JAPAN  JP -2                     TOKAI-1  GCR           NaN
# 59   JAPAN  JP -1                        JPDR  BWR           NaN
#
#     ThermalPower  Gross   Net  Operator  Provider  ...       Start  \
# 0           2660    912   866     HEPCO       MHI  ...  2004-11-01
# 1           3926   1206  1108  HOKURIKU   HITACHI  ...  2001-08-01
# 2           3293   1100  1067    TOHOKU   TOSHIBA  ...  2000-11-01
# 3           3926   1380  1325     CHUBU   TOSHIBA  ...  2000-07-01
# 4           2436    825   796    TOHOKU   TOSHIBA  ...  1998-01-01
# 5           3926   1356  1315     TEPCO   HITACHI  ...  1993-07-01
# 6           3926   1356  1315     TEPCO   TOSHIBA  ...  1992-11-01
# 7           3423   1180  1127    KYUSHU       MHI  ...  1992-07-01
# 8           2436    825   796    TOHOKU   TOSHIBA  ...  1991-04-01
# 9           2660    890   846   SHIKOKU       MHI  ...  1990-10-01
# 10          3293   1100  1067     TEPCO   HITACHI  ...  1990-03-01
# 11          3293   1137  1092     CHUBU   TOSHIBA  ...  1989-10-01
# 12          1593    540   505  HOKURIKU   HITACHI  ...  1989-07-01
# 13          3293   1100  1067     TEPCO   TOSHIBA  ...  1989-03-01
# 14          3423   1180  1127    KYUSHU       MHI  ...  1988-06-01
# 15          3423   1180  1127     KEPCO       MHI  ...  1988-06-01
# 16          3423   1180  1127     KEPCO       MHI  ...  1987-10-01
# 17           714    280   246      JAEA   T/H/F/M  ...  1986-05-01
# 18          3293   1100  1067     TEPCO   TOSHIBA  ...  1985-11-01
# 19          3293   1100  1067     TEPCO   HITACHI  ...  1985-06-01
# 20          1650    579   550     HEPCO       MHI  ...  1985-06-01
# 21          1650    579   550     HEPCO       MHI  ...  1985-04-01
# 22          2436    820   789   CHUGOKU   HITACHI  ...  1985-02-01
# 23          3293   1100  1056     CHUBU   TOSHIBA  ...  1983-04-01
# 24          3411   1160  1108     JAPCO       MHI  ...  1982-11-01
# 25          2660    890   846    KYUSHU       MHI  ...  1981-10-01
# 26          3293   1100  1067     TEPCO   HITACHI  ...  1981-05-01
# 27          2660    870   830     KEPCO       MHI  ...  1981-03-01
# 28          3293   1100  1067     TEPCO   TOSHIBA  ...  1981-03-01
# 29          2660    870   830     KEPCO       MHI  ...  1980-12-01
# 30          1593    524   498    TOHOKU   TOSHIBA  ...  1980-07-01
# 31          3293   1100  1067     TEPCO   TOSHIBA  ...  1980-06-01
# 32          2660    890   846    KYUSHU       MHI  ...  1979-12-01
# 33          3293   1100  1067     TEPCO   HITACHI  ...  1979-05-01
# 34          1650    566   538   SHIKOKU       MHI  ...  1978-08-01
# 35          1650    559   529    KYUSHU       MHI  ...  1977-02-01
# 36          3293   1100  1067     TEPCO   TOSHIBA  ...  1976-03-01
# 37          2436    840   806     CHUBU   TOSHIBA  ...  1974-06-01
# 38          3293   1100  1060     JAPCO        GE  ...  1973-10-01
# 39          3293   1100  1067     TEPCO      GE/T  ...  1973-10-01
# 40          1650    566   538   SHIKOKU       MHI  ...  1973-09-01
# 41          2381    784   760     TEPCO   HITACHI  ...  1973-02-01
# 42          3423   1175  1120     KEPCO        WH  ...  1972-12-01
# 43          3423   1175  1120     KEPCO        WH  ...  1972-10-01
# 44          2440    826   780     KEPCO       MHI  ...  1972-08-01
# 45           557    165   148      JAEA   HITACHI  ...  1972-05-01
# 46          2381    784   760     TEPCO   TOSHIBA  ...  1972-05-01
# 47          1650    559   529    KYUSHU       MHI  ...  1971-09-01
# 48          1593    540   515     CHUBU   TOSHIBA  ...  1971-06-01
# 49          2440    826   780     KEPCO       MHI  ...  1971-03-01
# 50          2381    784   760     TEPCO   TOSHIBA  ...  1970-12-01
# 51          1380    460   439   CHUGOKU   HITACHI  ...  1970-07-01
# 52          2440    826   780     KEPCO    WH/MHI  ...  1970-04-01
# 53          2381    784   760     TEPCO      GE/T  ...  1969-06-01
# 54          1456    500   470     KEPCO       MHI  ...  1968-05-01
# 55          1380    460   439     TEPCO  GE/GETSC  ...  1967-07-01
# 56          1031    340   320     KEPCO        WH  ...  1967-02-01
# 57          1070    357   340     JAPCO        GE  ...  1966-11-01
# 58           587    166   137     JAPCO       GEC  ...  1961-03-01
# 59            90     13    12      JAEA        GE  ...  1960-12-01
#
#     Connection            Operation    Shutdown Construction_time Online  \
# 0   2009-03-01  2009-12-01 00:00:00         NaN              1581   True
# 1   2005-07-01  2006-03-01 00:00:00         NaN              1430   True
# 2   2005-03-01  2005-12-01 00:00:00         NaN              1581   True
# 3   2004-04-01  2005-01-01 00:00:00         NaN              1370   True
# 4   2001-05-01  2002-01-01 00:00:00         NaN              1216   True
# 5   1996-12-01  1997-07-01 00:00:00         NaN              1249   True
# 6   1996-01-01  1996-11-01 00:00:00         NaN              1156   True
# 7   1996-11-01  1997-07-01 00:00:00         NaN              1584   True
# 8   1994-12-01  1995-07-01 00:00:00         NaN              1340   True
# 9   1994-03-01  1994-12-01 00:00:00         NaN              1247   True
# 10  1993-12-01  1994-08-01 00:00:00         NaN              1371   True
# 11  1993-01-01  1993-09-01 00:00:00         NaN              1188   True
# 12  1993-01-01  1993-07-01 00:00:00         NaN              1280   True
# 13  1992-12-01  1993-08-01 00:00:00         NaN              1371   True
# 14  1993-06-01  1994-03-01 00:00:00         NaN              1826   True
# 15  1992-06-01  1993-02-01 00:00:00         NaN              1461   True
# 16  1991-06-01  1991-12-01 00:00:00         NaN              1339   True
# 17  1995-08-01                  NaN  2017-12-01              3379  False
# 18  1990-02-01  1990-09-01 00:00:00         NaN              1553   True
# 19  1989-09-01  1990-04-01 00:00:00         NaN              1553   True
# 20  1990-08-01  1991-04-01 00:00:00         NaN              1887   True
# 21  1988-12-01  1989-06-01 00:00:00         NaN              1340   True
# 22  1988-07-01  1989-02-01 00:00:00         NaN              1246   True
# 23  1987-01-01  1987-08-01 00:00:00         NaN              1371   True
# 24  1986-06-01  1987-02-01 00:00:00         NaN              1308   True
# 25  1985-04-01  1985-11-01 00:00:00         NaN              1278   True
# 26  1986-12-01  1987-08-01 00:00:00  2019-09-01              2040  False
# 27  1984-11-01  1985-06-01 00:00:00         NaN              1341   True
# 28  1984-12-01  1985-06-01 00:00:00  2019-09-01              1371  False
# 29  1984-05-01  1985-01-01 00:00:00         NaN              1247   True
# 30  1983-11-01  1984-06-01 00:00:00  2018-12-01              1218  False
# 31  1985-02-01  1985-09-01 00:00:00         NaN              1706   True
# 32  1983-09-01  1984-07-01 00:00:00         NaN              1370   True
# 33  1983-06-01  1984-02-01 00:00:00  2019-09-01              1492  False
# 34  1981-08-01  1982-03-01 00:00:00  2018-05-01              1096  False
# 35  1980-06-01  1981-03-01 00:00:00  2019-04-01              1216  False
# 36  1981-07-01  1982-04-01 00:00:00  2019-09-01              1948  False
# 37  1978-05-01  1978-11-01 00:00:00  2009-01-01              1430  False
# 38  1978-03-01  1978-11-01 00:00:00         NaN              1612   True
# 39  1979-05-01  1979-10-01 00:00:00  2013-12-01              2038  False
# 40  1977-02-01  1977-09-01 00:00:00  2016-05-01              1249  False
# 41  1978-02-01  1978-10-01 00:00:00  2011-05-01              1826  False
# 42  1978-10-01  1979-12-01 00:00:00  2018-03-01              2130  False
# 43  1977-12-01  1979-03-01 00:00:00  2018-03-01              1887  False
# 44  1976-02-01  1976-12-01 00:00:00         NaN              1279   True
# 45  1978-07-01  1979-03-01 00:00:00  2003-03-01              2252  False
# 46  1977-09-01  1978-04-01 00:00:00  2013-12-01              1949  False
# 47  1975-02-01  1975-10-01 00:00:00  2015-04-01              1249  False
# 48  1974-08-01  1976-03-01 00:00:00  2009-01-01              1157  False
# 49  1975-01-01  1975-11-01 00:00:00         NaN              1402   True
# 50  1974-10-01  1976-03-01 00:00:00  2011-05-01              1400  False
# 51  1973-12-01                  NaN  2015-04-01              1249  False
# 52  1974-03-01  1974-11-01 00:00:00         NaN              1430   True
# 53  1973-12-01  1974-07-01 00:00:00  2011-05-01              1644  False
# 54  1972-04-01  1972-07-01 00:00:00  2015-04-01              1431  False
# 55  1970-11-01                  NaN  2011-05-01              1219  False
# 56  1970-08-01  1970-11-01 00:00:00  2015-04-01              1277  False
# 57  1969-11-01  1970-03-01 00:00:00  2015-04-01              1096  False
# 58  1965-11-01  1966-07-01 00:00:00  1998-03-01              1706  False
# 59  1963-10-01  1965-03-01 00:00:00  1976-03-01              1034  False
#
#     current_num   ctime_y  ctime_start  color_type
# 0            58  4.331507    55.871233     #377eb8
# 1            56  3.917808    52.616438     #ff7f00
# 2            55  4.331507    51.868493     #ff7f00
# 3            57  3.753425    51.531507     #ff7f00
# 4            54  3.331507    49.032877     #ff7f00
# 5            53  3.421918    44.526027     #ff7f00
# 6            52  3.167123    43.863014     #ff7f00
# 7            43  4.339726    43.526027     #377eb8
# 8            51  3.671233    42.273973     #ff7f00
# 9            44  3.416438    41.775342     #377eb8
# 10           50  3.756164    41.189041     #ff7f00
# 11           46  3.254795    40.775342     #ff7f00
# 12           45  3.506849    40.523288     #ff7f00
# 13           49  3.756164    40.189041     #ff7f00
# 14           42  5.002740    39.441096     #377eb8
# 15           48  4.002740    39.441096     #377eb8
# 16           47  3.668493    38.772603     #377eb8
# 17           20  9.257534    37.353425     #a65628
# 18           37  4.254795    36.857534     #ff7f00
# 19           38  4.254795    36.438356     #ff7f00
# 20           41  5.169863    36.438356     #377eb8
# 21           40  3.671233    36.271233     #377eb8
# 22           39  3.413699    36.109589     #ff7f00
# 23           35  3.756164    34.268493     #ff7f00
# 24           34  3.583562    33.854795     #377eb8
# 25           36  3.501370    32.769863     #377eb8
# 26           10  5.589041    32.350685     #ff7f00
# 27           32  3.673973    32.183562     #377eb8
# 28            9  3.756164    32.183562     #ff7f00
# 29           31  3.416438    31.936986     #377eb8
# 30           23  3.336986    31.517808     #ff7f00
# 31           33  4.673973    31.435616     #ff7f00
# 32           30  3.753425    30.934247     #377eb8
# 33            8  4.087671    30.347945     #ff7f00
# 34           16  3.002740    29.600000     #377eb8
# 35           12  3.331507    28.104110     #377eb8
# 36            7  5.336986    27.180822     #ff7f00
# 37           14  3.917808    25.430137     #ff7f00
# 38           29  4.416438    24.764384     #ff7f00
# 39            6  5.583562    24.764384     #ff7f00
# 40           15  3.421918    24.682192     #377eb8
# 41            4  5.002740    24.101370     #ff7f00
# 42           22  5.835616    23.931507     #377eb8
# 43           21  5.169863    23.764384     #377eb8
# 44           28  3.504110    23.597260     #377eb8
# 45            0  6.169863    23.345205     #999999
# 46            5  5.339726    23.345205     #ff7f00
# 47           11  3.421918    22.679452     #377eb8
# 48           13  3.169863    22.427397     #ff7f00
# 49           27  3.841096    22.175342     #377eb8
# 50            3  3.835616    21.928767     #ff7f00
# 51           24  3.421918    21.509589     #ff7f00
# 52           59  3.917808    21.260274     #377eb8
# 53            2  4.504110    20.427397     #ff7f00
# 54           19  3.920548    19.342466     #377eb8
# 55            1  3.339726    18.506849     #ff7f00
# 56           18  3.498630    18.095890     #377eb8
# 57           26  3.002740    17.843836     #ff7f00
# 58           25  4.673973    12.169863     #4daf4a
# 59           17  2.832877    11.923288     #ff7f00
#
# [60 rows x 22 columns]
